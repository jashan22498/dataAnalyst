# %% [markdown]
# # Movies Dataset Analysis

# %%
# Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt

plt.style.use('ggplot')

from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = [12, 8] # sets the size of the figure - [width, height]

# %%
# Reading the data into dataframe

# %%
movies = pd.read_csv("./movies.csv");

# %%
movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
movies.size
# Out:
# 115020

# %%
movies.shape
# Out:
# (7668, 15)

# %%
movies.shape[0]
# Out:
# 7668

# %%
len(movies)
# Out:
# 7668

# %%
movies.loc[0, :]
# Out:
# name                          The Shining
# rating                                  R
# genre                               Drama
# year                                 1980
# released    June 13, 1980 (United States)
# score                                 8.4
# votes                            927000.0
# director                  Stanley Kubrick
# writer                       Stephen King
# star                       Jack Nicholson
# country                    United Kingdom
# budget                         19000000.0
# gross                          46998772.0
# company                      Warner Bros.
# runtime                             146.0
# Name: 0, dtype: object

# %%
# Filling in missing values (NaN)

# %%
movies['budget']
# Out:
# 0       19000000.0
# 1        4500000.0
# 2       18000000.0
# 3        3500000.0
# 4        6000000.0
#            ...
# 7663        7000.0
# 7664           NaN
# 7665       58750.0
# 7666       15000.0
# 7667           NaN
# Name: budget, Length: 7668, dtype: float64

# %%
movies['budget'].isnull()[0:49]
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24     True
# 25     True
# 26     True
# 27    False
# 28    False
# 29    False
# 30     True
# 31     True
# 32     True
# 33    False
# 34     True
# 35    False
# 36    False
# 37    False
# 38     True
# 39     True
# 40     True
# 41     True
# 42    False
# 43     True
# 44     True
# 45     True
# 46    False
# 47    False
# 48    False
# Name: budget, dtype: bool

# %%
movies.loc[16, 'budget']
# Out:
# nan

# %%
np.mean(movies['budget'].isnull())
# Out:
# 0.2831246739697444

# %%
pd.isna(movies['name'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7663    False
# 7664    False
# 7665    False
# 7666    False
# 7667    False
# Name: name, Length: 7668, dtype: bool

# %%
np.mean(movies['name'].isnull())
# Out:
# 0.0

# %%
# Finding % of missing values in all columns

# %%
for col in movies.columns:
    missingPercent = np.mean(movies[col].isnull())
    print('{} - {}%'.format(col, missingPercent))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# Checking data types of movie attributes

# %%
movies.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# checking for empty(missing or null) values in 'budget' column

# %%
movies['budget'] == np.nan
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7663    False
# 7664    False
# 7665    False
# 7666    False
# 7667    False
# Name: budget, Length: 7668, dtype: bool

# %%
# filling missing values in 'budget' column with 0

# %%
movies['budget'].fillna(0, inplace = True)

# %%
movies['rating']
# Out:
# 0         R
# 1         R
# 2        PG
# 3        PG
# 4         R
#        ...
# 7663    NaN
# 7664    NaN
# 7665    NaN
# 7666    NaN
# 7667    NaN
# Name: rating, Length: 7668, dtype: object

# %%
# unique values and their count in 'rating' column

# %%
movies['rating'].value_counts()
# Out:
# rating
# R            3697
# PG-13        2112
# PG           1252
# Not Rated     283
# G             153
# Unrated        52
# NC-17          23
# TV-MA           9
# TV-PG           5
# X               3
# Approved        1
# TV-14           1
# Name: count, dtype: int64

# %%
# filling missing values in 'rating' column with 'Unrated'

# %%
movies['rating'].fillna('Unrated', inplace = True)

# %%
# unique values and their count in 'released' column

# %%
movies['released'].value_counts()
# Out:
# released
# February 14, 1986 (United States)    9
# May 17, 2019 (United States)         9
# October 4, 1991 (United States)      9
# August 26, 2016 (United States)      8
# October 11, 2002 (United States)     8
#                                     ..
# March 9, 2000 (Australia)            1
# July 20, 2001 (United Kingdom)       1
# October 11, 2000 (France)            1
# May 10, 2001 (Australia)             1
# August 19, 2020 (United States)      1
# Name: count, Length: 3414, dtype: int64

# %%
# filling missing values in 'released' column with 'February 14, 1986 (United States)'

# %%
movies['released'].fillna('February 14, 1986 (United States)', inplace = True)

# %%
# unique values and their count in 'score' column

# %%
movies['score'].value_counts()
# Out:
# score
# 6.6    359
# 6.4    351
# 6.2    346
# 6.7    332
# 6.5    331
#       ...
# 2.8      2
# 9.3      1
# 2.6      1
# 2.3      1
# 9.0      1
# Name: count, Length: 72, dtype: int64

# %%
# filling missing values in 'score' column with 6.6

# %%
movies['score'].fillna(6.6, inplace = True)

# %%
# unique values and their count in 'votes' column

# %%
movies['votes'].value_counts()
# Out:
# votes
# 13000.0     117
# 11000.0     116
# 14000.0     105
# 19000.0     102
# 15000.0     102
#            ...
# 270000.0      1
# 810000.0      1
# 639.0         1
# 390.0         1
# 7.0           1
# Name: count, Length: 936, dtype: int64

# %%
# filling missing values in 'votes' column with 13000.0

# %%
movies['votes'].fillna(13000.0, inplace = True)

# %%
# unique values and their count in 'writer' column

# %%
movies['writer'].value_counts()
# Out:
# writer
# Woody Allen            37
# Stephen King           31
# Luc Besson             26
# John Hughes            25
# William Shakespeare    15
#                        ..
# Daniel G. Sullivan      1
# Bonnie Turner           1
# Dick King-Smith         1
# Helen Prejean           1
# Pereko Mosia            1
# Name: count, Length: 4535, dtype: int64

# %%
# filling missing values in 'writer' column with 'Woody Allen'

# %%
movies['writer'].fillna('Woody Allen', inplace = True)

# %%
# Finding faster way to populate missing values in all fields

# %%
type(movies['writer'].value_counts())
# Out:
# pandas.core.series.Series

# %%
np.max(movies['writer'].value_counts())
# Out:
# 40

# %%
movies['writer'].value_counts().index[0]
# Out:
# 'Woody Allen'

# %%
movies['writer'].value_counts().values[0]
# Out:
# 40

# %%
# iterating over all columns, if a column contains nan(s), they are filled with the most repeating value in that column

# %%
for col in movies.columns:
    if(np.mean(movies[col].isnull()) > 0):
        movies[col].fillna(movies[col].value_counts().index[0], inplace = True)

# %%
# rechecking for nan(s) in movies df

# %%
movies.isnull()
# Out:
#        name  rating  genre   year  released  score  votes  director  writer  \
# 0     False   False  False  False     False  False  False     False   False
# 1     False   False  False  False     False  False  False     False   False
# 2     False   False  False  False     False  False  False     False   False
# 3     False   False  False  False     False  False  False     False   False
# 4     False   False  False  False     False  False  False     False   False
# ...     ...     ...    ...    ...       ...    ...    ...       ...     ...
# 7663  False   False  False  False     False  False  False     False   False
# 7664  False   False  False  False     False  False  False     False   False
# 7665  False   False  False  False     False  False  False     False   False
# 7666  False   False  False  False     False  False  False     False   False
# 7667  False   False  False  False     False  False  False     False   False
#
#        star  country  budget  gross  company  runtime
# 0     False    False   False  False    False    False
# 1     False    False   False  False    False    False
# 2     False    False   False  False    False    False
# 3     False    False   False  False    False    False
# 4     False    False   False  False    False    False
# ...     ...      ...     ...    ...      ...      ...
# 7663  False    False   False  False    False    False
# 7664  False    False   False  False    False    False
# 7665  False    False   False  False    False    False
# 7666  False    False   False  False    False    False
# 7667  False    False   False  False    False    False
#
# [7668 rows x 15 columns]

# %%
# count of nan(s) per column

# %%
movies.isna().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
np.mean(movies.isnull())
# Out:
# 0.0

# %%
movies.head(5)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
# splitting 'released' column into 'year' and 'country' columns

# %%
type(movies['released'])
# Out:
# pandas.core.series.Series

# %%
movies.loc[0, 'released']
# Out:
# 'June 13, 1980 (United States)'

# %%
type(movies.loc[0, 'released'])
# Out:
# str

# %%
# Partially working approach

# %%
# movies.loc[0, 'released'].find('(')

# %%
# movies.loc[0, 'released'].find(')')

# %%
# movies.iloc[0, 4]

# %%
# movies.iloc[0, 4][(movies.loc[0, 'released'].find('(') + 1):(movies.loc[0, 'released'].find(')'))]

# %%
# movies['Country'] = None

# %%
# movies.head()

# %%
# movies['Country'] = movies['released'].str.split(pat = '(').str[1].str.split(pat = ')').str[0]

# %%
# movies['Country']

# %%
# len(movies.loc[0, 'Country'])

# %%
# movies.head()

# %%
# movies['date'] = None

# %%
# movies['date'] = movies['released'].str.split(pat = '(').str[0]

# %%
# movies.head()

# %%
# type(movies.loc[0, 'date'])

# %%
# movies['date'] = movies['date'].str[:-1]

# %%
# movies.loc[0, 'released']

# %%
# importing re module for regex functions

# %%
import re

# %%
# finding 4 consecutive digits in 'released' column's every cell to be used as a 'Year' column's cells

# %%
movies['Year'] = movies['released'].apply(lambda x: re.findall('\d{4}', x)).str[0]

# %%
# typecasting 'Year' column's values from 'str' to 'int'

# %%
movies['Year'] = movies['Year'].astype('int64')

# %%
np.sort(movies.Year)
# Out:
# array([1980, 1980, 1980, ..., 2020, 2020, 2020], dtype=int64)

# %%
movies['Year'].value_counts()
# Out:
# Year
# 2019    228
# 2015    213
# 1986    213
# 2011    212
# 2007    212
# 2003    207
# 1994    206
# 1998    205
# 2018    205
# 2001    205
# 2008    204
# 1991    204
# 1995    203
# 2017    203
# 2000    200
# 2013    200
# 2005    200
# 1993    200
# 1989    200
# 1988    199
# 1996    199
# 1997    198
# 2016    198
# 1990    197
# 2006    196
# 1999    196
# 1987    196
# 2014    196
# 2010    193
# 2002    193
# 2009    192
# 2012    192
# 2004    191
# 1992    184
# 1985    183
# 1984    157
# 1983    145
# 1982    128
# 1981    103
# 1980     80
# 2020     32
# Name: count, dtype: int64

# %%
# movies[movies['Year'].isin(['(United', 'States)', '(Australia)'])]

# %%
movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime  Year
# 0   46998772.0        Warner Bros.    146.0  1980
# 1   58853106.0   Columbia Pictures    104.0  1980
# 2  538375067.0           Lucasfilm    124.0  1980
# 3   83453539.0  Paramount Pictures     88.0  1980
# 4   39846344.0      Orion Pictures     98.0  1980

# %%
movies[movies.year != movies.Year]
# Out:
#                                   name     rating      genre  year  \
# 8                          Superman II         PG     Action  1980
# 11              The Gods Must Be Crazy         PG  Adventure  1980
# 21                       Heaven's Gate          R  Adventure  1980
# 33    Cattle Annie and Little Britches         PG      Drama  1980
# 40            The Watcher in the Woods         PG     Family  1980
# ...                                ...        ...        ...   ...
# 7525               Weathering with You      PG-13  Animation  2019
# 7580               Run with the Hunted  Not Rated      Crime  2019
# 7584                Faith, Hope & Love         PG     Comedy  2019
# 7604                            Mine 9  Not Rated      Drama  2019
# 7641          By Light of Desert Night    Unrated      Drama  2019
#
#                               released  score     votes            director  \
# 8        June 19, 1981 (United States)    6.8  101000.0      Richard Lester
# 11    October 26, 1984 (United States)    7.3   54000.0           Jamie Uys
# 21      April 24, 1981 (United States)    6.8   14000.0      Michael Cimino
# 33      April 24, 1981 (United States)    6.1     604.0      Lamont Johnson
# 40     October 9, 1981 (United States)    6.3    5700.0          John Hough
# ...                                ...    ...       ...                 ...
# 7525  January 17, 2020 (United States)    7.5   28000.0      Makoto Shinkai
# 7580     June 26, 2020 (United States)    5.2     735.0           John Swab
# 7584      February 4, 2020 (Australia)    6.2     719.0        J.J. Englert
# 7604             May 19, 2020 (Poland)    6.4    4400.0       Eddie Mensore
# 7641     March 3, 2020 (United States)    4.8     373.0  David Stuart Snell
#
#                   writer                star        country      budget  \
# 8           Jerry Siegel        Gene Hackman  United States  54000000.0
# 11             Jamie Uys               N!xau   South Africa   5000000.0
# 21        Michael Cimino  Kris Kristofferson  United States  44000000.0
# 33            David Eyre         Scott Glenn  United States   5100000.0
# 40         Brian Clemens         Bette Davis  United States         0.0
# ...                  ...                 ...            ...         ...
# 7525      Makoto Shinkai        Kotaro Daigo          Japan  11100000.0
# 7580           John Swab         Ron Perlman  United States         0.0
# 7584       Robert Krantz     Peta Murgatroyd  United States         0.0
# 7604       Eddie Mensore       Terry Serpico  United States    350000.0
# 7641  David Stuart Snell    Alexandra Bokova  United States         0.0
#
#             gross                              company  runtime  Year
# 8     108185706.0                       Dovemead Films    127.0  1981
# 11     30031783.0                         C.A.T. Films    109.0  1984
# 21      3484523.0                 Partisan Productions    219.0  1981
# 33       534816.0             Cattle Annie Productions     97.0  1981
# 40      5000000.0              Walt Disney Productions     84.0  1981
# ...           ...                                  ...      ...   ...
# 7525  193457467.0  "Weathering With You" Film Partners    112.0  2020
# 7580        682.0                        Roxwell Films     93.0  2020
# 7584     210091.0                   Ellinas Multimedia    106.0  2020
# 7604     226421.0                       Emphatic Films     83.0  2020
# 7641   14000000.0                         Canyon Media     94.0  2020
#
# [1326 rows x 16 columns]

# %%
movies = movies.drop('year', axis = 1)

# %%
movies.rename(columns = {'Year': 'year'}, inplace = True)

# %%
# fetching 'Country' from 'released'

# %%
movies['Country'] = movies['released'].apply(lambda x: re.findall('[(].*[)]', x)).str[0].str[1:-1]

# %%
movies['Country'][0]
# Out:
# 'United States'

# %%
movies[movies.country != movies.Country]
# Out:
#                         name   rating      genre  \
# 0                The Shining        R      Drama
# 11    The Gods Must Be Crazy       PG  Adventure
# 20                  Cruising        R      Crime
# 27         Raise the Titanic       PG     Action
# 31                Prom Night        R     Horror
# ...                      ...      ...        ...
# 7653              The Quarry        R      Crime
# 7655   Legend of Deification    TV-PG  Animation
# 7657                    Leap  Unrated      Drama
# 7665           Saving Mbango  Unrated      Drama
# 7667               Tee em el  Unrated     Horror
#
#                                 released  score     votes           director  \
# 0          June 13, 1980 (United States)    8.4  927000.0    Stanley Kubrick
# 11      October 26, 1984 (United States)    7.3   54000.0          Jamie Uys
# 20     February 15, 1980 (United States)    6.5   20000.0   William Friedkin
# 27        August 1, 1980 (United States)    5.0    4100.0      Jerry Jameson
# 31         July 18, 1980 (United States)    5.4   16000.0         Paul Lynch
# ...                                  ...    ...       ...                ...
# 7653             April 17, 2020 (Mexico)    5.4    2400.0        Scott Teems
# 7655     October 1, 2020 (United States)    6.6    1300.0         Teng Cheng
# 7657  September 25, 2020 (United States)    6.7     903.0  Peter Ho-Sun Chan
# 7665           April 27, 2020 (Cameroon)    5.7      29.0       Nkanya Nkwai
# 7667     August 19, 2020 (United States)    5.7       7.0       Pereko Mosia
#
#                 writer              star         country      budget  \
# 0         Stephen King    Jack Nicholson  United Kingdom  19000000.0
# 11           Jamie Uys             N!xau    South Africa   5000000.0
# 20    William Friedkin         Al Pacino    West Germany  11000000.0
# 27        Adam Kennedy     Jason Robards  United Kingdom  36000000.0
# 31        William Gray    Leslie Nielsen          Canada         0.0
# ...                ...               ...             ...         ...
# 7653       Scott Teems      Shea Whigham   United States         0.0
# 7655       Woody Allen    Guangtao Jiang           China         0.0
# 7657          Ji Zhang           Gong Li           China         0.0
# 7665      Lynno Lovert      Onyama Laura   United States     58750.0
# 7667      Pereko Mosia  Siyabonga Mabaso    South Africa         0.0
#
#             gross                     company  runtime  year        Country
# 0      46998772.0                Warner Bros.    146.0  1980  United States
# 11     30031783.0                C.A.T. Films    109.0  1984  United States
# 20     19814523.0  Lorimar Film Entertainment    102.0  1980  United States
# 27     14000000.0                   ITC Films    115.0  1980  United States
# 31     14796236.0      Guardian Trust Company     92.0  1980  United States
# ...           ...                         ...      ...   ...            ...
# 7653       3661.0            Prowess Pictures     98.0  2020         Mexico
# 7655  240663149.0    Beijing Enlight Pictures    110.0  2020  United States
# 7657   25818882.0          Universal Pictures    135.0  2020  United States
# 7665   14000000.0            Embi Productions     97.0  2020       Cameroon
# 7667   14000000.0                 PK 65 Films    102.0  2020  United States
#
# [2094 rows x 16 columns]

# %%
movies = movies.drop('country', axis = 1)

# %%
movies['Country'].value_counts()
# Out:
# Country
# United States     6737
# United Kingdom     197
# France             148
# Australia           48
# Germany             46
#                   ...
# Austria              1
# Soviet Union         1
# Uruguay              1
# Yugoslavia           1
# Cameroon             1
# Name: count, Length: 61, dtype: int64

# %%
movies.rename(columns = {'Country': 'country'}, inplace = True)

# %%
movies
# Out:
#                                                 name   rating      genre  \
# 0                                        The Shining        R      Drama
# 1                                    The Blue Lagoon        R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back       PG     Action
# 3                                          Airplane!       PG     Comedy
# 4                                         Caddyshack        R     Comedy
# ...                                              ...      ...        ...
# 7663                                    More to Life  Unrated      Drama
# 7664                                     Dream Round  Unrated     Comedy
# 7665                                   Saving Mbango  Unrated      Drama
# 7666                                    It's Just Us  Unrated      Drama
# 7667                                       Tee em el  Unrated     Horror
#
#                               released  score      votes         director  \
# 0        June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1         July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2        June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3         July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4        July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
# ...                                ...    ...        ...              ...
# 7663  October 23, 2020 (United States)    3.1       18.0    Joseph Ebanks
# 7664  February 7, 2020 (United States)    4.7       36.0     Dusty Dukatz
# 7665         April 27, 2020 (Cameroon)    5.7       29.0     Nkanya Nkwai
# 7666   October 1, 2020 (United States)    6.6    13000.0    James Randall
# 7667   August 19, 2020 (United States)    5.7        7.0     Pereko Mosia
#
#                        writer              star      budget        gross  \
# 0                Stephen King    Jack Nicholson  19000000.0   46998772.0
# 1     Henry De Vere Stacpoole    Brooke Shields   4500000.0   58853106.0
# 2              Leigh Brackett       Mark Hamill  18000000.0  538375067.0
# 3                Jim Abrahams       Robert Hays   3500000.0   83453539.0
# 4          Brian Doyle-Murray       Chevy Chase   6000000.0   39846344.0
# ...                       ...               ...         ...          ...
# 7663            Joseph Ebanks      Shannon Bond      7000.0   14000000.0
# 7664              Lisa Huston  Michael Saquella         0.0   14000000.0
# 7665             Lynno Lovert      Onyama Laura     58750.0   14000000.0
# 7666            James Randall     Christina Roz     15000.0   14000000.0
# 7667             Pereko Mosia  Siyabonga Mabaso         0.0   14000000.0
#
#                         company  runtime  year        country
# 0                  Warner Bros.    146.0  1980  United States
# 1             Columbia Pictures    104.0  1980  United States
# 2                     Lucasfilm    124.0  1980  United States
# 3            Paramount Pictures     88.0  1980  United States
# 4                Orion Pictures     98.0  1980  United States
# ...                         ...      ...   ...            ...
# 7663         Universal Pictures     90.0  2020  United States
# 7664  Cactus Blue Entertainment     90.0  2020  United States
# 7665           Embi Productions     97.0  2020       Cameroon
# 7666         Universal Pictures    120.0  2020  United States
# 7667                PK 65 Films    102.0  2020  United States
#
# [7668 rows x 15 columns]

# %%
# movies = movies.drop('released', axis = 1)

# %%
movies[(movies['genre'] == 'Comedy') & (movies['score'] > 6) & (movies['year'] >= 2018)]
# Out:
#                                      name     rating   genre  \
# 2219                               Hyenas  Not Rated  Comedy
# 7040             This Beautiful Fantastic         PG  Comedy
# 7100                  The Death of Stalin          R  Comedy
# 7103                           The Upside      PG-13  Comedy
# 7123                        Thoroughbreds          R  Comedy
# 7249                       A Simple Favor          R  Comedy
# 7256                    Crazy Rich Asians      PG-13  Comedy
# 7268          Mamma Mia! Here We Go Again      PG-13  Comedy
# 7270                       Instant Family      PG-13  Comedy
# 7272                         Eighth Grade          R  Comedy
# 7304                          Love, Simon      PG-13  Comedy
# 7305                 Mary Poppins Returns         PG  Comedy
# 7326                               Mid90s          R  Comedy
# 7332                             Blockers          R  Comedy
# 7339                        Blindspotting          R  Comedy
# 7348                            Book Club      PG-13  Comedy
# 7350                  Sorry to Bother You          R  Comedy
# 7367  The House with a Clock in Its Walls         PG  Comedy
# 7384                      Forever My Girl         PG  Comedy
# 7398                                Tully          R  Comedy
# 7406                            Wild Rose          R  Comedy
# 7415                        Juliet, Naked          R  Comedy
# 7420                     Super Troopers 2          R  Comedy
# 7433                          Gloria Bell          R  Comedy
# 7444     Once Upon a Time... In Hollywood          R  Comedy
# 7451                            Yesterday      PG-13  Comedy
# 7452                             Parasite          R  Comedy
# 7454                           Knives Out      PG-13  Comedy
# 7459                          Jojo Rabbit      PG-13  Comedy
# 7475                            Booksmart          R  Comedy
# 7482                       Marriage Story          R  Comedy
# 7485                             Hustlers          R  Comedy
# 2              Leigh Brackett       Mark Hamill  18000000.0  538375067.0
# 3                Jim Abrahams       Robert Hays   3500000.0   83453539.0
# 4          Brian Doyle-Murray       Chevy Chase   6000000.0   39846344.0
# ...                       ...               ...         ...          ...
# 7663            Joseph Ebanks      Shannon Bond      7000.0   14000000.0
# 7664              Lisa Huston  Michael Saquella         0.0   14000000.0
# 7665             Lynno Lovert      Onyama Laura     58750.0   14000000.0
# 7666            James Randall     Christina Roz     15000.0   14000000.0
# 7667             Pereko Mosia  Siyabonga Mabaso         0.0   14000000.0
#
#                         company  runtime  year        country
# 0                  Warner Bros.    146.0  1980  United States
# 1             Columbia Pictures    104.0  1980  United States
# 2                     Lucasfilm    124.0  1980  United States
# 3            Paramount Pictures     88.0  1980  United States
# 4                Orion Pictures     98.0  1980  United States
# ...                         ...      ...   ...            ...
# 7663         Universal Pictures     90.0  2020  United States
# 7664  Cactus Blue Entertainment     90.0  2020  United States
# 7665           Embi Productions     97.0  2020       Cameroon
# 7666         Universal Pictures    120.0  2020  United States
# 7667                PK 65 Films    102.0  2020  United States
#
# [7668 rows x 15 columns]

# %%
movies.dtypes
# Out:
# name         object
# rating       object
# genre        object
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# year          int64
# country      object
# dtype: object

# %%
# Typecasting

# %%
movies['budget'].astype('str').str[-1].value_counts()
# Out:
# budget
# 0    7668
# Name: count, dtype: int64

# %%
movies['budget'] = movies['budget'].astype('int64')

# %%
movies['votes'].astype('str').str[-1].value_counts()
# Out:
# votes
# 0    7668
# Name: count, dtype: int64

# %%
movies.votes = movies.votes.astype('int64')

# %%
movies['gross'].astype('str').str[-1].value_counts()
# Out:
# gross
# 0    7668
# Name: count, dtype: int64

# %%
movies['gross'] = movies['gross'].astype('int64')

# %%
movies['runtime'].astype('str').str[-1].value_counts()
# Out:
# runtime
# 0    7668
# Name: count, dtype: int64

# %%
movies['runtime'] = movies['runtime'].astype('int64')

# %%
# sorting 'gross' column in decreasing order to get an idea of movie revenue

# %%
movies.sort_values(by = ['gross'], inplace = False, ascending = False)
# Out:
#                                             name     rating   genre  \
# 5445                                      Avatar      PG-13  Action
# 7445                           Avengers: Endgame      PG-13  Action
# 3045                                     Titanic      PG-13   Drama
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action
# 7244                      Avengers: Infinity War      PG-13  Action
# ...                                          ...        ...     ...
# 3818                        Love, Honor and Obey          R  Comedy
# 7625                            The Untold Story    Unrated  Comedy
# 7580                         Run with the Hunted  Not Rated   Crime
# 2417                                    Madadayo    Unrated   Drama
# 3203                                  Trojan War      PG-13  Comedy
#
#                                released  score    votes         director  \
# 5445  December 18, 2009 (United States)    7.8  1100000    James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000    Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000    James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000      J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000    Anthony Russo
# ...                                 ...    ...      ...              ...
# 3818   February 9, 2001 (United States)    6.5     5200  Dominic Anciano
# 7625   January 11, 2019 (United States)    5.7      320    Shane Stanley
# 7580      June 26, 2020 (United States)    5.2      735        John Swab
# 2417             April 17, 1993 (Japan)    7.3     5100   Akira Kurosawa
# 3203           October 1, 1997 (Brazil)    5.7     5800     George Huang
#
#                   writer               star     budget       gross  \
# 5445       James Cameron    Sam Worthington  237000000  2847246203
# 7445  Christopher Markus  Robert Downey Jr.  356000000  2797501328
# 3045       James Cameron  Leonardo DiCaprio  200000000  2201647264
# 6663     Lawrence Kasdan       Daisy Ridley  245000000  2069521700
# 7244  Christopher Markus  Robert Downey Jr.  321000000  2048359754
# ...                  ...                ...        ...         ...
# 3818     Dominic Anciano        Sadie Frost          0        1400
# 7625         Lee Stanley        Miko Hughes          0         790
# 7580           John Swab        Ron Perlman          0         682
# 2417        Ishirô Honda   Tatsuo Matsumura   11900000         596
# 3203           Andy Burg       Will Friedle   15000000         309
#
#                                      company  runtime  year        country
# 5445                   Twentieth Century Fox      162  2009  United States
# 7445                          Marvel Studios      181  2019  United States
# 3045                   Twentieth Century Fox      194  1997  United States
# 6663                               Lucasfilm      138  2015  United States
# 7244                          Marvel Studios      149  2018  United States
# ...                                      ...      ...   ...            ...
# 3818  British Broadcasting Corporation (BBC)      103  2001  United States
# 7625               Visual Arts Entertainment      104  2019  United States
# 7580                           Roxwell Films       93  2020  United States
# 2417          DENTSU Music And Entertainment      134  1993          Japan
# 3203                                Daybreak       85  1997         Brazil
#
# [7668 rows x 15 columns]

# %%
# To get window of all records

pd.set_option('display.max_rows', None)

# %%
movies.head()
# Out:
#                                              name rating      genre  \
# 0                                     The Shining      R      Drama
# 1                                 The Blue Lagoon      R  Adventure
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action
# 3                                       Airplane!     PG     Comedy
# 4                                      Caddyshack      R     Comedy
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star    budget      gross  \
# 0             Stephen King  Jack Nicholson  19000000   46998772
# 1  Henry De Vere Stacpoole  Brooke Shields   4500000   58853106
# 2           Leigh Brackett     Mark Hamill  18000000  538375067
# 3             Jim Abrahams     Robert Hays   3500000   83453539
# 4       Brian Doyle-Murray     Chevy Chase   6000000   39846344
#
#               company  runtime  year        country
# 0        Warner Bros.      146  1980  United States
# 1   Columbia Pictures      104  1980  United States
# 2           Lucasfilm      124  1980  United States
# 3  Paramount Pictures       88  1980  United States
# 4      Orion Pictures       98  1980  United States

# %%
movies['company'].sort_values(ascending = False).head()
# Out:
# 7129                     thefyzz
# 5664                 micro_scope
# 6412    iDeal Partners Film Fund
# 4007                    i5 Films
# 6793                  i am OTHER
# Name: company, dtype: object

# %%
movies['company'].drop_duplicates().sort_values(ascending = False).head()
# Out:
# 7129                     thefyzz
# 5664                 micro_scope
# 6412    iDeal Partners Film Fund
# 4007                    i5 Films
# 6793                  i am OTHER
# Name: company, dtype: object

# %%
movies['company'].drop_duplicates().head()
# Out:
# 0          Warner Bros.
# 1     Columbia Pictures
# 2             Lucasfilm
# 3    Paramount Pictures
# 4        Orion Pictures
# Name: company, dtype: object

# %%
movies.drop_duplicates().head()
# Out:
#                                              name rating      genre  \
# 0                                     The Shining      R      Drama
# 1                                 The Blue Lagoon      R  Adventure
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action
# 3                                       Airplane!     PG     Comedy
# 4                                      Caddyshack      R     Comedy
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star    budget      gross  \
# 0             Stephen King  Jack Nicholson  19000000   46998772
# 1  Henry De Vere Stacpoole  Brooke Shields   4500000   58853106
# 2           Leigh Brackett     Mark Hamill  18000000  538375067
# 3             Jim Abrahams     Robert Hays   3500000   83453539
# 4       Brian Doyle-Murray     Chevy Chase   6000000   39846344
#
#               company  runtime  year        country
# 0        Warner Bros.      146  1980  United States
# 1   Columbia Pictures      104  1980  United States
# 2           Lucasfilm      124  1980  United States
# 3  Paramount Pictures       88  1980  United States
# 4      Orion Pictures       98  1980  United States

# %%
movies.head()
# Out:
#                                              name rating      genre  \
# 0                                     The Shining      R      Drama
# 1                                 The Blue Lagoon      R  Adventure
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action
# 3                                       Airplane!     PG     Comedy
# 4                                      Caddyshack      R     Comedy
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star    budget      gross  \
# 0             Stephen King  Jack Nicholson  19000000   46998772
# 1  Henry De Vere Stacpoole  Brooke Shields   4500000   58853106
# 2           Leigh Brackett     Mark Hamill  18000000  538375067
# 3             Jim Abrahams     Robert Hays   3500000   83453539
# 4       Brian Doyle-Murray     Chevy Chase   6000000   39846344
#
#               company  runtime  year        country
# 0        Warner Bros.      146  1980  United States
# 1   Columbia Pictures      104  1980  United States
# 2           Lucasfilm      124  1980  United States
# 3  Paramount Pictures       88  1980  United States
# 4      Orion Pictures       98  1980  United States

# %%
len(movies)
# Out:
# 7668

# %%
movies.to_csv('./cleanedMovies.csv')
