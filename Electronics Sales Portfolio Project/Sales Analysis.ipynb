# %% [markdown]
# # Sales Analysis of an Electronics Store in US

# %%
# importing necessary libraries

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
# reading a single csv file into AprilSales df
AprilSales = pd.read_csv("./Sales_Data/Sales_April_2019.csv")

# %%
AprilSales
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
# listing all files in the 'Sales_Data' directory
files = [file for file in os.listdir('./Sales_Data')]

# %%
# List of all 12 months' sales files

# %%
files
# Out:
# ['.ipynb_checkpoints',
#  'Sales_April_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_September_2019.csv']

# %%
for file in files:
    print(file)
# Out:
# .ipynb_checkpoints
# Sales_April_2019.csv
# Sales_August_2019.csv
# Sales_December_2019.csv
# Sales_February_2019.csv
# Sales_January_2019.csv
# Sales_July_2019.csv
# Sales_June_2019.csv
# Sales_March_2019.csv
# Sales_May_2019.csv
# Sales_November_2019.csv
# Sales_October_2019.csv
# Sales_September_2019.csv

# %%
# removivg first file name from list 'files', as it is not a sales data file

# %%
files.pop(0)
# Out:
# '.ipynb_checkpoints'

# %%
files
# Out:
# ['Sales_April_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_September_2019.csv']

# %%
# creating an empty dataframe
all_months_data = pd.DataFrame()

# %%
all_months_data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# one by one reading each file in files and appending it to 'all_months_data' df

for file in files:
    all_months_data = pd.concat([all_months_data, pd.read_csv('./Sales_Data/' + file)])

# %%
all_months_data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %%
all_months_data.index = np.arange(0, len(all_months_data), 1)

# %%
all_months_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
all_months_data.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
all_months_data.loc[0, 'Order Date']
# Out:
# '04/19/19 08:46'

# %% [markdown]
# # What was the best month for sales? How much was earned that month

# %%
# Data Cleaning

# %%
all_months_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
# finding rows with all NaN values

# %%
all_months_data[all_months_data.isna().all(axis = 1)]
# Out:
#        Order ID Product Quantity Ordered Price Each Order Date  \
# 1           NaN     NaN              NaN        NaN        NaN
# 356         NaN     NaN              NaN        NaN        NaN
# 735         NaN     NaN              NaN        NaN        NaN
# 1433        NaN     NaN              NaN        NaN        NaN
# 1553        NaN     NaN              NaN        NaN        NaN
# ...         ...     ...              ...        ...        ...
# 185176      NaN     NaN              NaN        NaN        NaN
# 185438      NaN     NaN              NaN        NaN        NaN
# 186042      NaN     NaN              NaN        NaN        NaN
# 186548      NaN     NaN              NaN        NaN        NaN
# 186826      NaN     NaN              NaN        NaN        NaN
#
#        Purchase Address
# 1                   NaN
# 356                 NaN
# 735                 NaN
# 1433                NaN
# 1553                NaN
# ...                 ...
# 185176              NaN
# ...

# %%
all_months_data.dropna(axis = 0, how = 'all', inplace = True)

# %%
all_months_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
len(all_months_data)
# Out:
# 186305

# %%
all_months_data.index = np.arange(0, len(all_months_data), 1)

# %%
all_months_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1        176559  Bose SoundSport Headphones                1      99.99
# 2        176560                Google Phone                1        600
# 3        176560            Wired Headphones                1      11.99
# 4        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186300   259353      AAA Batteries (4-pack)                3       2.99
# 186301   259354                      iPhone                1        700
# 186302   259355                      iPhone                1        700
# 186303   259356      34in Ultrawide Monitor                1     379.99
# 186304   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
# finding columns with any NaN

# %%
all_months_data.isna().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
# Adding additional columns to 'all_months_data' df

# %%
all_months_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
all_months_data.loc[0]
# Out:
# Order ID                                  176558
# Product                     USB-C Charging Cable
# Quantity Ordered                               2
# Price Each                                 11.95
# Order Date                        04/19/19 08:46
# Purchase Address    917 1st St, Dallas, TX 75001
# Name: 0, dtype: object

# %%
type(all_months_data.loc[0])
# Out:
# pandas.core.series.Series

# %%
for cell in all_months_data.loc[0]:
    print(type(cell))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
all_months_data['Month'] = all_months_data['Order Date'].str[:2]

# %%
# Finding all 'Or's in 'Month' column
all_months_data[all_months_data['Month'] == 'Or']
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 517     Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1146    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1152    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2869    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2884    Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...          ...      ...               ...         ...         ...
# 184624  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 185009  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186019  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186088  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186194  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#         Purchase Address Month
# 517     Purchase Address    Or
# 1146    Purchase Address    Or
# 1152    Purchase Address    Or
# ...

# %%
# keeping all rows where 'Month' column's value is not 'Or'

# %%
all_months_data = all_months_data[all_months_data['Month'] != 'Or']

# %%
all_months_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1        176559  Bose SoundSport Headphones                1      99.99
# 2        176560                Google Phone                1        600
# 3        176560            Wired Headphones                1      11.99
# 4        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186300   259353      AAA Batteries (4-pack)                3       2.99
# 186301   259354                      iPhone                1        700
# 186302   259355                      iPhone                1        700
# 186303   259356      34in Ultrawide Monitor                1     379.99
# 186304   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address Month
# ...

# %%
all_months_data.index = range(0, len(all_months_data))

# %%
all_months_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1        176559  Bose SoundSport Headphones                1      99.99
# 2        176560                Google Phone                1        600
# 3        176560            Wired Headphones                1      11.99
# 4        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 185945   259353      AAA Batteries (4-pack)                3       2.99
# 185946   259354                      iPhone                1        700
# 185947   259355                      iPhone                1        700
# 185948   259356      34in Ultrawide Monitor                1     379.99
# 185949   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address Month
# ...

# %%
all_months_data.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# Month               object
# dtype: object

# %%
# changing data type of numeric columns
all_months_data = all_months_data.astype({"Order ID": int, "Quantity Ordered": int, "Price Each": float, "Month": int})

# %%
for cell in all_months_data.loc[0]:
    print(type(cell))
# Out:
# <class 'numpy.int32'>
# <class 'str'>
# <class 'numpy.int32'>
# <class 'numpy.float64'>
# <class 'str'>
# <class 'str'>
# <class 'numpy.int32'>

# %%
type(all_months_data.iloc[0, 6])
# Out:
# numpy.int32

# %%
all_months_data
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185946    259354                      iPhone                 1      700.00
# 185947    259355                      iPhone                 1      700.00
# 185948    259356      34in Ultrawide Monitor                 1      379.99
# 185949    259357        USB-C Charging Cable                 1       11.95
#
# ...

# %%
# Adding a sales column
all_months_data['Sales'] = all_months_data['Quantity Ordered'] * all_months_data['Price Each']

# %%
all_months_data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 4    176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99

# %%
# grouping data based on 'Month' Column and then selecting sum of sales for each month

# %%
monthlySales = all_months_data.groupby('Month')['Sales'].sum()
monthlySales
# Out:
# Month
# 1     1822256.73
# 2     2202022.42
# 3     2807100.38
# 4     3390670.24
# 5     3152606.75
# 6     2577802.26
# 7     2647775.76
# 8     2244467.88
# 9     2097560.13
# 10    3736726.88
# 11    3199603.20
# 12    4613443.34
# Name: Sales, dtype: float64

# %%
type(monthlySales)
# Out:
# pandas.core.series.Series

# %%
monthlySales.sort_values()
# Out:
# Month
# 1     1822256.73
# 9     2097560.13
# 2     2202022.42
# 8     2244467.88
# 6     2577802.26
# 7     2647775.76
# 3     2807100.38
# 5     3152606.75
# 11    3199603.20
# 4     3390670.24
# 10    3736726.88
# 12    4613443.34
# Name: Sales, dtype: float64

# %% [markdown]
# # Dec. was the best sales month with sales = 4613443.34 USD

# %%
# Plotting a Bar Chart to show each month's total sales

# %%
from matplotlib.pyplot import figure

# %%
figure(figsize = (10, 8), dpi = 80)

months = range(1, 13)
plt.bar(months, monthlySales)
plt.xticks(months)
plt.ylabel('Total Sales (USD)')
plt.xlabel('Month Number')

plt.title('Monthly Sales - Bar Graph')

plt.show()

# %%
pd.DataFrame({'Month Number': monthlySales.index, 'Total Sales (USD)': monthlySales.values}).to_csv('./monthlySales.csv', index = False)

# %% [markdown]
# # Which city had the maximum sales?

# %%
# Adding a 'City' column

# %%
all_months_data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 4    176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99

# %%
# 1. by using apply() method
all_months_data['City'] = all_months_data['Purchase Address'].apply(lambda x: x.split(',')[1][1:])

# %%
# 2.
def get_city(address):
    return address.split(',')[1][1:]

all_months_data['City'] = all_months_data['Purchase Address'].apply(lambda x: get_city(x))

# %%
all_months_data
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185946    259354                      iPhone                 1      700.00
# 185947    259355                      iPhone                 1      700.00
# 185948    259356      34in Ultrawide Monitor                 1      379.99
# 185949    259357        USB-C Charging Cable                 1       11.95
#
# ...

# %%
all_months_data.loc[0, 'City']
# Out:
# 'Dallas'

# %%
# Count of Orders by City

# %%
all_months_data.City.value_counts()
# Out:
# City
# San Francisco    44732
# Los Angeles      29605
# New York City    24876
# Boston           19934
# Atlanta          14881
# Dallas           14820
# Seattle          14732
# Portland         12465
# Austin            9905
# Name: count, dtype: int64

# %%
# Portland appears in multiple states, finding corresponding states and separating them

# %%
all_months_data[all_months_data.City == 'Portland']
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 27        176583      AAA Batteries (4-pack)                 2        2.99
# 39        176593    Lightning Charging Cable                 2       14.95
# 63        176617    Apple Airpods Headphones                 1      150.00
# 88        176642       AA Batteries (4-pack)                 1        3.84
# 92        176646          Macbook Pro Laptop                 1     1700.00
# ...          ...                         ...               ...         ...
# 185784    259202  Bose SoundSport Headphones                 1       99.99
# 185794    259210    Lightning Charging Cable                 1       14.95
# 185807    259223       AA Batteries (4-pack)                 1        3.84
# 185877    259291                      iPhone                 1      700.00
# 185914    259323        USB-C Charging Cable                 1       11.95
#
# ...

# %%
# 'Portland' is in two states ('OR' and 'ME')

# %%
# Adding state to 'City' column

def get_state(address):
    return address.split(',')[2][1:3]

all_months_data.City = all_months_data.City + ' (' + all_months_data['Purchase Address'].apply(lambda x: get_state(x)) + ')'

# %%
all_months_data
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185946    259354                      iPhone                 1      700.00
# 185947    259355                      iPhone                 1      700.00
# 185948    259356      34in Ultrawide Monitor                 1      379.99
# 185949    259357        USB-C Charging Cable                 1       11.95
#
# ...

# %%
all_months_data.dtypes
# Out:
# Order ID              int32
# Product              object
# Quantity Ordered      int32
# Price Each          float64
# Order Date           object
# Purchase Address     object
# Month                 int32
# Sales               float64
# City                 object
# dtype: object

# %%
# aggregating data based on 'City' and summing all sales values in each city, then fetching total sales for each city

# %%
citySales = all_months_data.groupby('City')['Sales'].sum()

# %%
citySales
# Out:
# City
# Atlanta (GA)          2795498.58
# Austin (TX)           1819581.75
# Boston (MA)           3661642.01
# Dallas (TX)           2767975.40
# Los Angeles (CA)      5452570.80
# New York City (NY)    4664317.43
# Portland (ME)          449758.27
# Portland (OR)         1870732.34
# San Francisco (CA)    8262203.91
# Seattle (WA)          2747755.48
# Name: Sales, dtype: float64

# %%
citySales.sort_values()
# Out:
# City
# Portland (ME)          449758.27
# Austin (TX)           1819581.75
# Portland (OR)         1870732.34
# Seattle (WA)          2747755.48
# Dallas (TX)           2767975.40
# Atlanta (GA)          2795498.58
# Boston (MA)           3661642.01
# New York City (NY)    4664317.43
# Los Angeles (CA)      5452570.80
# San Francisco (CA)    8262203.91
# Name: Sales, dtype: float64

# %%
type(citySales)
# Out:
# pandas.core.series.Series

# %%
citySales.values
# Out:
# array([2795498.58, 1819581.75, 3661642.01, 2767975.4 , 5452570.8 ,
#        4664317.43,  449758.27, 1870732.34, 8262203.91, 2747755.48])

# %%
citySales.index
# Out:
# Index(['Atlanta (GA)', 'Austin (TX)', 'Boston (MA)', 'Dallas (TX)',
#        'Los Angeles (CA)', 'New York City (NY)', 'Portland (ME)',
#        'Portland (OR)', 'San Francisco (CA)', 'Seattle (WA)'],
#       dtype='object', name='City')

# %%
type(citySales.values)
# Out:
# numpy.ndarray

# %%
type(citySales.index)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# # San Francisco (CA) was the best sales city with sales = 8262203.91 USD

# %%
# Plotting a bar chart of 'City' versus 'Total Sales (USD)'

# %%
figure(figsize = (12, 8), dpi = 80)

plt.title('Bar Chart - Total Sales by City')
plt.bar(citySales.index, citySales.values)
plt.xticks(rotation = 'vertical')
plt.ylabel('Total Sales (USD)')
plt.xlabel('City')

plt.show()

# %%
pd.DataFrame({'City': citySales.index, 'Total Sales (USD)': citySales.values}).to_csv('./citySales.csv', index = False)

# %% [markdown]
# # What time should we display advertisements to maximize the likelihood of consumer's buying product?

# %%
# Ads should be displayed at that time(s) of the day when consumers are ordering high amounts of orders

# %%
all_months_data
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185946    259354                      iPhone                 1      700.00
# 185947    259355                      iPhone                 1      700.00
# 185948    259356      34in Ultrawide Monitor                 1      379.99
# 185949    259357        USB-C Charging Cable                 1       11.95
#
# ...

# %%
# converting 'Order Date' from 'object' to 'datetime'

# %%
all_months_data['Order Date'] = pd.to_datetime(arg = all_months_data['Order Date'], format = '%m/%d/%y %H:%M')

# %%
all_months_data
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185946    259354                      iPhone                 1      700.00
# 185947    259355                      iPhone                 1      700.00
# 185948    259356      34in Ultrawide Monitor                 1      379.99
# 185949    259357        USB-C Charging Cable                 1       11.95
#
# ...

# %%
all_months_data.dtypes
# Out:
# Order ID                     int32
# Product                     object
# Quantity Ordered             int32
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address            object
# Month                        int32
# Sales                      float64
# City                        object
# dtype: object

# %%
all_months_data.iloc[0, 4]
# Out:
# Timestamp('2019-04-19 08:46:00')

# %%
type(all_months_data.iloc[0, 4])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# adding 'Hour' and 'Minute' columns to 'all_months_data' df

# %%
all_months_data['Hour'] = all_months_data['Order Date'].dt.hour
all_months_data['Minute'] = all_months_data['Order Date'].dt.minute

# %%
all_months_data
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185946    259354                      iPhone                 1      700.00
# 185947    259355                      iPhone                 1      700.00
# 185948    259356      34in Ultrawide Monitor                 1      379.99
# 185949    259357        USB-C Charging Cable                 1       11.95
#
# ...

# %%
all_months_data.dtypes
# Out:
# Order ID                     int32
# Product                     object
# Quantity Ordered             int32
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address            object
# Month                        int32
# Sales                      float64
# City                        object
# Hour                         int32
# Minute                       int32
# dtype: object

# %%
hours = all_months_data['Hour'].unique()
hours
# Out:
# array([ 8, 22, 14,  9, 13,  7, 10, 17, 12, 19, 15, 20, 18,  0, 11, 23, 21,
#         4, 16,  5,  2,  1,  6,  3])

# %%
hours.size
# Out:
# 24

# %%
type(hours)
# Out:
# numpy.ndarray

# %%
# grouping data by 'Hour' column

# %%
hour_groups = all_months_data.groupby('Hour')

# %%
hour_groups.groups
# Out:
# {0: [19, 24, 56, 113, 123, 132, 218, 283, 450, 478, 548, 645, 646, 649, 650, 660, 699, 705, 824, 856, 875, 936, 1040, 1100, 1137, 1205, 1257, 1276, 1277, 1339, 1342, 1344, 1403, 1631, 1731, 1749, 1777, 1839, 1926, 2170, 2225, 2250, 2369, 2388, 2407, 2535, 2572, 2618, 2619, 2622, 2701, 2719, 2744, 2873, 2945, 3067, 3068, 3254, 3270, 3294, 3296, 3297, 3365, 3399, 3422, 3568, 3591, 3633, 3702, 3754, 3828, 3839, 3859, 3891, 4026, 4039, 4184, 4202, 4245, 4266, 4302, 4432, 4466, 4516, 4556, 4610, 4745, 4756, 4776, 4783, 4794, 4884, 4913, 4938, 4948, 5007, 5027, 5145, 5176, 5220, ...], 1: [94, 186, 265, 364, 451, 499, 638, 671, 836, 880, 896, 1012, 1062, 1077, 1091, 1126, 1192, 1208, 1246, 1351, 1712, 1780, 1781, 1782, 1811, 1928, 1993, 2008, 2150, 2161, 2172, 2342, 2396, 2461, 2485, 2528, 2529, 2548, 2616, 2656, 2688, 2712, 2795, 2812, 2859, 2860, 2920, 3103, 3122, 3239, 3267, 3384, 3669, 3675, 3700, 3732, 3785, 3786, 3825, 3942, 4010, 4084, 4149, 4179, 4220, 4241, 4391, 4427, 4474, 4484, 
# ...

# %%
type(hour_groups)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
type(hour_groups.groups)
# Out:
# pandas.io.formats.printing.PrettyDict

# %%
hourlyOrders = hour_groups.count()
hourlyOrders
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# Hour
# 0         3910     3910              3910        3910        3910
# 1         2350     2350              2350        2350        2350
# 2         1243     1243              1243        1243        1243
# 3          831      831               831         831         831
# 4          854      854               854         854         854
# 5         1321     1321              1321        1321        1321
# 6         2482     2482              2482        2482        2482
# 7         4011     4011              4011        4011        4011
# 8         6256     6256              6256        6256        6256
# 9         8748     8748              8748        8748        8748
# 10       10944    10944             10944       10944       10944
# 11       12411    12411             12411       12411       12411
# 12       12587    12587             12587       12587       12587
# ...

# %%
type(hourlyOrders)
# Out:
# pandas.core.frame.DataFrame

# %%
hourlyOrders.sort_values(by = 'Order ID', ascending = False)
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# Hour
# 19       12905    12905             12905       12905       12905
# 12       12587    12587             12587       12587       12587
# 11       12411    12411             12411       12411       12411
# 18       12280    12280             12280       12280       12280
# 20       12228    12228             12228       12228       12228
# 13       12129    12129             12129       12129       12129
# 14       10984    10984             10984       10984       10984
# 10       10944    10944             10944       10944       10944
# 21       10921    10921             10921       10921       10921
# 17       10899    10899             10899       10899       10899
# 16       10384    10384             10384       10384       10384
# 15       10175    10175             10175       10175       10175
# 22        8822     8822              8822        8822        8822
# ...

# %% [markdown]
# # Maximum number of orders are placed between 7pm and 8pm or 12pm and 1pm; these two are peak hours for ads to be placed

# %%
# line graph to show orders count per hour of the day

# %%
figure(figsize = (10, 8), dpi = 80)

plt.title('Line Graph - Hourly Orders')

plt.plot(np.sort(hours), hourlyOrders['Order ID'])

plt.xticks(hours)
plt.grid()

plt.xlabel('Hour')
plt.ylabel('Number of Orders')

plt.show()

# %%
pd.DataFrame({'Hour': np.sort(hours), 'Orders Count': hourlyOrders['Order ID']}).to_csv('./hourlyOrders.csv', index = False)

# %% [markdown]
# # Around 12pm or 7pm = Advertisements time

# %% [markdown]
# # Which products are most often sold together?

# %%
# getting unique order ids and their correspnding data

# %%
O_IDs = all_months_data['Order ID'].value_counts()
O_IDs
# Out:
# Order ID
# 160873    5
# 178158    4
# 277875    4
# 196615    4
# 304802    4
#          ..
# 158177    1
# 158178    1
# 158179    1
# 158180    1
# 259357    1
# Name: count, Length: 178437, dtype: int64

# %%
type(O_IDs)
# Out:
# pandas.core.series.Series

# %%
O_IDs[176560]
# Out:
# 2

# %%
O_IDs.index
# Out:
# Index([160873, 178158, 277875, 196615, 304802, 235798, 193511, 263918, 289117,
#        296353,
#        ...
#        158172, 158173, 158174, 158175, 158176, 158177, 158178, 158179, 158180,
#        259357],
#       dtype='int32', name='Order ID', length=178437)

# %%
O_IDs.values
# Out:
# array([5, 4, 4, ..., 1, 1, 1], dtype=int64)

# %%
O_IDs  = O_IDs[O_IDs > 1]
O_IDs
# Out:
# Order ID
# 160873    5
# 178158    4
# 277875    4
# 196615    4
# 304802    4
#          ..
# 257079    2
# 254455    2
# 216943    2
# 253366    2
# 182756    2
# Name: count, Length: 7136, dtype: int64

# %%
Multi_Product_O_IDs = all_months_data[all_months_data['Order ID'].isin(O_IDs.index)]

# %%
Multi_Product_O_IDs
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 17        176574                Google Phone                 1      600.00
# 18        176574        USB-C Charging Cable                 1       11.95
# 29        176585  Bose SoundSport Headphones                 1       99.99
# ...          ...                         ...               ...         ...
# 185893    259303       AA Batteries (4-pack)                 1        3.84
# 185904    259314            Wired Headphones                 1       11.99
# 185905    259314      AAA Batteries (4-pack)                 2        2.99
# 185941    259350                Google Phone                 1      600.00
# 185942    259350        USB-C Charging Cable                 1       11.95
#
# ...

# %%
Multi_Product_O_IDs.index = range(0, len(Multi_Product_O_IDs))

# %%
Multi_Product_O_IDs
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176560                Google Phone                 1      600.00
# 1        176560            Wired Headphones                 1       11.99
# 2        176574                Google Phone                 1      600.00
# 3        176574        USB-C Charging Cable                 1       11.95
# 4        176585  Bose SoundSport Headphones                 1       99.99
# ...         ...                         ...               ...         ...
# 14644    259303       AA Batteries (4-pack)                 1        3.84
# 14645    259314            Wired Headphones                 1       11.99
# 14646    259314      AAA Batteries (4-pack)                 2        2.99
# 14647    259350                Google Phone                 1      600.00
# 14648    259350        USB-C Charging Cable                 1       11.95
#
#                Order Date                       Purchase Address  Month  \
# ...

# %%
O_ID_Groups = Multi_Product_O_IDs.groupby('Order ID')

# %%
O_ID_Groups

# %%
type(O_ID_Groups)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
O_ID_Groups.groups
# Out:
# {141275: [5250, 5251], 141290: [5252, 5253], 141365: [5254, 5255], 141384: [5256, 5257], 141450: [5258, 5259], 141457: [5260, 5261], 141478: [5262, 5263], 141550: [5264, 5265, 5266], 141587: [5267, 5268], 141645: [5269, 5270], 141738: [5271, 5272], 141782: [5273, 5274], 141789: [5275, 5276], 141795: [5277, 5278], 141809: [5279, 5280], 141843: [5281, 5282], 141900: [5283, 5284, 5285], 141901: [5286, 5287], 141910: [5288, 5289], 141939: [5290, 5291], 141946: [5292, 5293], 141947: [5294, 5295], 141965: [5296, 5297], 141967: [5298, 5299], 141970: [5300, 5301], 141972: [5302, 5303], 141993: [5304, 5305], 142010: [5306, 5307], 142023: [5308, 5309], 142037: [5310, 5311], 142039: [5312, 5313], 142048: [5314, 5315], 142071: [5316, 5317], 142085: [5318, 5319], 142112: [5320, 5321], 142128: [5322, 5323, 5324], 142144: [5325, 5326], 142145: [5327, 5328], 142192: [5329, 5330], 142230: [5331, 5332], 142261: [5333, 5334], 142287: [5335, 5336, 5337], 142299: [5338, 5339], 142308: [5340, 5341], 14231
# ...

# %%
type(O_ID_Groups.groups)
# Out:
# pandas.io.formats.printing.PrettyDict

# %%
O_ID_Groups['Product']

# %%
type(O_ID_Groups['Product'])
# Out:
# pandas.core.groupby.generic.SeriesGroupBy

# %%
O_ID_Groups['Product'].get_group(141275)
# Out:
# 5250    USB-C Charging Cable
# 5251        Wired Headphones
# Name: Product, dtype: object

# %%
type(O_ID_Groups['Product'].get_group(141275))
# Out:
# pandas.core.series.Series

# %%
O_ID_Groups['Product'].get_group(141275).tolist()
# Out:
# ['USB-C Charging Cable', 'Wired Headphones']

# %%
MultiProductOrders = O_ID_Groups['Product'].apply(lambda x: x.tolist())

# %%
MultiProductOrders
# Out:
# Order ID
# 141275             [USB-C Charging Cable, Wired Headphones]
# 141290    [Apple Airpods Headphones, AA Batteries (4-pack)]
# 141365                  [Vareebadd Phone, Wired Headphones]
# 141384                 [Google Phone, USB-C Charging Cable]
# 141450           [Google Phone, Bose SoundSport Headphones]
#                                 ...
# 319536               [Macbook Pro Laptop, Wired Headphones]
# 319556                     [Google Phone, Wired Headphones]
# 319584                           [iPhone, Wired Headphones]
# 319596                   [iPhone, Lightning Charging Cable]
# 319631    [34in Ultrawide Monitor, Lightning Charging Ca...
# Name: Product, Length: 7136, dtype: object

# %%
type(MultiProductOrders)
# Out:
# pandas.core.series.Series

# %%
MultiProductOrders.value_counts()
# Out:
# Product
# [iPhone, Lightning Charging Cable]                                                  882
# [Google Phone, USB-C Charging Cable]                                                856
# [iPhone, Wired Headphones]                                                          361
# [Vareebadd Phone, USB-C Charging Cable]                                             312
# [Google Phone, Wired Headphones]                                                    303
#                                                                                    ...
# [Google Phone, USB-C Charging Cable, USB-C Charging Cable]                            1
# [ThinkPad Laptop, 27in 4K Gaming Monitor]                                             1
# [iPhone, Google Phone]                                                                1
# [Vareebadd Phone, 27in FHD Monitor]                                                   1
# [Google Phone, USB-C Charging Cable, Wired Headphones, Apple Airpods Headphones]      1
# ...

# %%
pd.DataFrame({'Products': MultiProductOrders.value_counts()[0:5].index, 
              'Order Frequency': MultiProductOrders.value_counts()[0:5].values}).to_csv('./Pair_of_Products_Sales.csv', index = False)

# %%
SortedMultiOrders = MultiProductOrders.apply(lambda x: len(x)).sort_values(ascending = False)

# %%
SortedMultiOrders[0:5]
# Out:
# Order ID
# 160873    5
# 263918    4
# 289117    4
# 196615    4
# 304802    4
# Name: Product, dtype: int64

# %%
all_months_data[all_months_data['Order ID'].isin(SortedMultiOrders[0:5].index)]
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 39782     304802                Google Phone                 1      600.00
# 39783     304802        USB-C Charging Cable                 1       11.95
# 39784     304802  Bose SoundSport Headphones                 1       99.99
# 39785     304802      34in Ultrawide Monitor                 1      379.99
# 66026     160873                      iPhone                 1      700.00
# 66027     160873    Lightning Charging Cable                 1       14.95
# 66028     160873    Apple Airpods Headphones                 1      150.00
# 66029     160873            Wired Headphones                 1       11.99
# 66030     160873                Google Phone                 1      600.00
# 122546    196615                Google Phone                 1      600.00
# 122547    196615        USB-C Charging Cable                 1       11.95
# ...

# %%
s = MultiProductOrders[MultiProductOrders.index.isin(SortedMultiOrders[0:5].index)]

# %%
pd.DataFrame({'OrderID': s.index, 'Product List': s.values}).to_csv('./BiggestMultiOrder.csv', index = False)

# %% [markdown]
# # [iPhone, Lightning Charging Cable] and [Google Phone, USB-C Charging Cable] are the two pairs of products which are most often sold together

# %% [markdown]
# # Which product sold the most and why?

# %%
all_months_data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 4    176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                City  Hour  Minute
# 0       Dallas (TX)     8      46
# ...

# %%
# grouping data based on 'Product' column

# %%
productGroups = all_months_data.groupby('Product')
productGroups

# %%
# finding sum of 'Quantity Ordered' for each product

# %%
salesPerProduct = productGroups['Quantity Ordered'].sum()
salesPerProduct
# Out:
# Product
# 20in Monitor                   4129
# 27in 4K Gaming Monitor         6244
# 27in FHD Monitor               7550
# 34in Ultrawide Monitor         6199
# AA Batteries (4-pack)         27635
# AAA Batteries (4-pack)        31017
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# Flatscreen TV                  4819
# Google Phone                   5532
# LG Dryer                        646
# LG Washing Machine              666
# Lightning Charging Cable      23217
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# USB-C Charging Cable          23975
# Vareebadd Phone                2068
# Wired Headphones              20557
# iPhone                         6849
# Name: Quantity Ordered, dtype: int32

# %%
type(salesPerProduct)
# Out:
# pandas.core.series.Series

# %%
salesPerProduct.sort_values()
# Out:
# Product
# LG Dryer                        646
# LG Washing Machine              666
# Vareebadd Phone                2068
# 20in Monitor                   4129
# ThinkPad Laptop                4130
# Macbook Pro Laptop             4728
# Flatscreen TV                  4819
# Google Phone                   5532
# 34in Ultrawide Monitor         6199
# 27in 4K Gaming Monitor         6244
# iPhone                         6849
# 27in FHD Monitor               7550
# Bose SoundSport Headphones    13457
# Apple Airpods Headphones      15661
# Wired Headphones              20557
# Lightning Charging Cable      23217
# USB-C Charging Cable          23975
# AA Batteries (4-pack)         27635
# AAA Batteries (4-pack)        31017
# Name: Quantity Ordered, dtype: int32

# %%
# plotting a bar chart to show total items sold per product

# %%
figure(figsize = (10, 8), dpi = 80)

plt.title('Bar Chart - Total Sales per Product')

plt.bar(salesPerProduct.index, salesPerProduct.values)
plt.xticks(rotation = 'vertical')
plt.ylabel('Total Sales (Quantity Ordered)')
plt.xlabel('Product')

plt.show()

# %%
# AAA Batteries was the most sold Product and LG Dryer was the least one
# One reason could be significant price differences
# Another reason could be batteries are used in most of the electronic items

# %%
prices = productGroups['Price Each'].mean()

# %%
prices
# Out:
# Product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# Vareebadd Phone                400.00
# Wired Headphones                11.99
# iPhone                         700.00
# Name: Price Each, dtype: float64

# %%
all_months_data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 4    176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                City  Hour  Minute
# 0       Dallas (TX)     8      46
# ...

# %%
pd.DataFrame({'Product': salesPerProduct.index, 'Total Quantity Ordered': salesPerProduct.values}).to_csv('./Items Sold per Product.csv', index = False)
